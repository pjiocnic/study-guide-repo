# %% [markdown]
# # Colab-ready notebook: DistilBERT + Imbalance Toolkit by GPT

# %% [markdown]
# What you get:
#
# * Class-weighted cross-entropy **or** **focal loss** (toggle).
# * Optional **WeightedRandomSampler** for balanced batches.
# * Macro-F1 + per-class metrics & confusion matrix.
# * Optional **two-stage** regimen (head-only → full model).

# %%
# =========================================================
# 0) Setup (Colab): installs
# =========================================================
# !pip -q install "transformers>=4.44" "datasets>=2.20" "evaluate>=0.4.2" "accelerate>=0.33" scikit-learn matplotlib --upgrade
